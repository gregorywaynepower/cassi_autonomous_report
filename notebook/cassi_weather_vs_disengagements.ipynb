# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
df = pd.read_csv('../data/cassi_weather.csv', parse_dates=True, index_col='time')
df.drop(columns=['snow', 'wpgt', 'tsun'], inplace=True)
df.coco = df.coco.astype("category")
df.rename(columns={'temp':'Temperature_Celsius','rhum':'Relative_Humidity_%','dwpt':'Dew_Point','prcp':'Precipitation','wdir':'Wind_Direction_Degrees','wspd':'Windspeed_mph','pres':'Air_Pressure_hPa','coco':'Weather_Condition'},inplace=True)
df
# Out:
#                      Temperature_Celsius  Dew_Point  Relative_Humidity_%  \
# time
# 2023-03-01 00:00:00                 20.0        4.9                 37.0
# 2023-03-01 01:00:00                 16.7        5.6                 48.0
# 2023-03-01 02:00:00                 13.3        5.7                 60.0
# 2023-03-01 03:00:00                 12.2        4.9                 61.0
# 2023-03-01 04:00:00                 15.0        4.4                 49.0
# ...                                  ...        ...                  ...
# 2023-06-02 19:00:00                 27.2       16.8                 53.0
# 2023-06-02 20:00:00                 27.8       17.3                 53.0
# 2023-06-02 21:00:00                 28.3       17.2                 51.0
# 2023-06-02 22:00:00                 28.0       16.9                 51.0
# 2023-06-02 23:00:00                 26.1       17.2                 58.0
#
#                      Precipitation  Wind_Direction_Degrees  Windspeed_mph  \
# time
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2256 entries, 2023-03-01 00:00:00 to 2023-06-02 23:00:00
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature_Celsius     2256 non-null   float64
#  1   Dew_Point               2256 non-null   float64
#  2   Relative_Humidity_%     2256 non-null   float64
#  3   Precipitation           2256 non-null   float64
#  4   Wind_Direction_Degrees  2256 non-null   float64
#  5   Windspeed_mph           2256 non-null   float64
#  6   Air_Pressure_hPa        2256 non-null   float64
#  7   Weather_Condition       2256 non-null   category
# dtypes: category(1), float64(7)
# memory usage: 143.6 KB
